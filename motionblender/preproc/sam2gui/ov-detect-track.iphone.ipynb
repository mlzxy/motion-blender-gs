# %%
# %load_ext autoreload
# %autoreload 2

GIT_ROOT_LINES = !git rev-parse --show-toplevel
WORK_DIR = GIT_ROOT_LINES[0]
import sys

# assume that grounded-sam-2 is installed in `Grounded-SAM-2` at project root
GROUNDING_SAM2_PATH = "${WORK_DIR}/Grounded-SAM-2"
sys.path.append(GROUNDING_SAM2_PATH)

TEXT_PROMPT_DICT = {
    'iphone': {
        "teddy": "person.teddy bear.",
        "apple": "person.apple.",
        "backpack": "person.backpack.",
        "block": "person.block.", # needs reverse track
        "pillow": "person.pillow."                
    }
}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import shutil
import cv2
import torch
import numpy as np
import supervision as sv
from glob import glob
from torchvision.ops import box_convert
from pathlib import Path
from tqdm import tqdm
from PIL import Image
from sam2.build_sam import build_sam2_video_predictor, build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor 
from grounding_dino.groundingdino.util.inference import load_model, load_image, predict
from utils.track_utils import sample_points_from_masks
from utils.video_utils import create_video_from_images
from transformers import AutoProcessor, AutoModelForZeroShotObjectDetection 
from utils.track_utils import sample_points_from_masks
from utils.video_utils import create_video_from_images
from utils.common_utils import CommonUtils
from utils.mask_dictionary_model import MaskDictionaryModel, ObjectInfo
import json
import copy


def reverse_files(folder_path):
    # Get all files in the directory, excluding subdirectories
    files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    
    # Sort the files lexicographically
    sorted_files = sorted(files)
    
    # Determine the number of pairs to swap
    n = len(sorted_files)
    for i in tqdm(range(n // 2), desc=f"Swapping files in {folder_path}"):
        # Get the i-th file from the start and end
        file1 = sorted_files[i]
        file2 = sorted_files[n - i - 1]
        
        # Full paths for the files
        path1 = os.path.join(folder_path, file1)
        path2 = os.path.join(folder_path, file2)
        
        # Read the contents of both files
        with open(path1, 'rb') as f:
            content1 = f.read()
        with open(path2, 'rb') as f:
            content2 = f.read()
        
        # Write the swapped contents back to the files
        with open(path1, 'wb') as f:
            f.write(content2)
        with open(path2, 'wb') as f:
            f.write(content1)
        

    

"""
Hyperparam for Ground and Tracking
"""
ROOT = "/scratch/xz653/datasets/iphone"
GROUNDING_DINO_CONFIG = "grounding_dino/groundingdino/config/GroundingDINO_SwinT_OGC.py"
GROUNDING_DINO_CHECKPOINT = "gdino_checkpoints/groundingdino_swint_ogc.pth"

# change them for better results
BOX_THRESHOLD = 0.35
TEXT_THRESHOLD = 0.25
REDETECT_INTERVAL = 1000

SCENE_NAME = 'pillow'

REVERSE_TRACK = False
VIDEO_PATH = os.path.join(ROOT, SCENE_NAME, 'rgb/1x/0_*.png')

SAVE_TRACKING_RESULTS_DIR = os.path.join(ROOT, SCENE_NAME, 'flow3d_preprocessed/grounding_sam2')
OUTPUT_VIDEO_PATH = os.path.join(SAVE_TRACKING_RESULTS_DIR, 'output.mp4')

TEXT_PROMPT = TEXT_PROMPT_DICT['iphone'][SCENE_NAME]


# SAVE_TRACKING_RESULTS_DIR = "./tracking_results"
# OUTPUT_VIDEO_PATH = "./output.mp4"


############################################ 
ALL_DETECTIONS_OUTPUT = []

SOURCE_VIDEO_FRAME_DIR = "/tmp/custom_video_frames"

PROMPT_TYPE_FOR_VIDEO = "box" # choose from ["point", "box", "mask"]
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"


for tmp_folder in [SOURCE_VIDEO_FRAME_DIR, ]:
    if os.path.exists(tmp_folder):
        shutil.rmtree(tmp_folder)
    Path(tmp_folder).mkdir(parents=True, exist_ok=True)

output_dir = SAVE_TRACKING_RESULTS_DIR
mask_data_dir = os.path.join(output_dir, "mask_data")
json_data_dir = os.path.join(output_dir, "json_data")
result_dir = os.path.join(output_dir, "result")
CommonUtils.creat_dirs(mask_data_dir)
CommonUtils.creat_dirs(json_data_dir)
# Out:
# Path '/scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/mask_data' did not exist and has been created.
# Path '/scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/json_data' did not exist and has been created.

# %%
"""
Custom video input directly using video files
"""
if VIDEO_PATH.endswith(".mp4"):
    print("Extracting frames from video...")
    video_info = sv.VideoInfo.from_video_path(VIDEO_PATH)  # get video info
    print(video_info)
    frame_generator = sv.get_video_frames_generator(VIDEO_PATH, stride=1, start=0, end=None)

    # saving video to frames
    source_frames = Path(SOURCE_VIDEO_FRAME_DIR)
    source_frames.mkdir(parents=True, exist_ok=True)

    with sv.ImageSink(
        target_dir_path=source_frames, 
        overwrite=True, 
        image_name_pattern="{:05d}.jpg"
    ) as sink:
        for frame in tqdm(frame_generator, desc="Saving Video Frames"):
            sink.save_image(frame)
else:
    # VIDEO_PATH is a glob pattern
    im_paths = sorted(glob(VIDEO_PATH))
    print(f'images from {VIDEO_PATH}', len(im_paths))
    for i, im_path in enumerate(tqdm(im_paths)):
        im = Image.open(im_path)
        bname = os.path.splitext(os.path.basename(im_path))[0]
        im.convert("RGB").save(os.path.join(SOURCE_VIDEO_FRAME_DIR, f"{bname}.jpg"))

    if REVERSE_TRACK:
        reverse_files(SOURCE_VIDEO_FRAME_DIR)
# Out:
# images from /scratch/xz653/datasets/iphone/pillow/rgb/1x/0_*.png 330
# 100%|██████████| 330/330 [00:10<00:00, 32.85it/s]

# %% [markdown]
# # Multi Frame Grounding

# %%
# init grounding dino model from huggingface
model_id = "IDEA-Research/grounding-dino-base"
processor = AutoProcessor.from_pretrained(model_id)
grounding_model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(DEVICE)
# Out:
# UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].

# %%
# init sam image predictor and video predictor model
sam2_checkpoint = GROUNDING_SAM2_PATH + "/checkpoints/sam2.1_hiera_large.pt"
model_cfg = "configs/sam2.1/sam2.1_hiera_l.yaml"

video_predictor = build_sam2_video_predictor(model_cfg, sam2_checkpoint)
sam2_image_model = build_sam2(model_cfg, sam2_checkpoint)
image_predictor = SAM2ImagePredictor(sam2_image_model)

# %%
# init video predictor state
inference_state = video_predictor.init_state(video_path=SOURCE_VIDEO_FRAME_DIR)
step = REDETECT_INTERVAL # the step to sample frames for Grounding DINO predictor

sam2_masks = MaskDictionaryModel()
PROMPT_TYPE_FOR_VIDEO = "mask" # box, mask or point
objects_count = 0
frame_object_count = {}


sam2_masks = MaskDictionaryModel()
PROMPT_TYPE_FOR_VIDEO = "mask" # box, mask or point
objects_count = 0
frame_object_count = {}
frame_names = [
    p for p in os.listdir(SOURCE_VIDEO_FRAME_DIR)
    if os.path.splitext(p)[-1] in [".jpg", ".jpeg", ".JPG", ".JPEG"]
]
frame_names.sort(key=lambda p: int(os.path.splitext(p)[0]))
text = TEXT_PROMPT
device = DEVICE
video_dir = SOURCE_VIDEO_FRAME_DIR
output_video_path = OUTPUT_VIDEO_PATH


"""
Step 2: Prompt Grounding DINO and SAM image predictor to get the box and mask for all frames
"""
print("Total frames:", len(frame_names))
for start_frame_idx in range(0, len(frame_names), step):
# prompt grounding dino to get the box coordinates on specific frame
    print("start_frame_idx", start_frame_idx)
    # continue
    img_path = os.path.join(video_dir, frame_names[start_frame_idx])
    image = Image.open(img_path).convert("RGB")
    image_base_name = frame_names[start_frame_idx].split(".")[0]
    mask_dict = MaskDictionaryModel(promote_type = PROMPT_TYPE_FOR_VIDEO, mask_name = f"mask_{image_base_name}.npy")

    # run Grounding DINO on the image
    inputs = processor(images=image, text=text, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = grounding_model(**inputs)

    results = processor.post_process_grounded_object_detection(
        outputs,
        inputs.input_ids,
        box_threshold=BOX_THRESHOLD,
        text_threshold=TEXT_THRESHOLD,
        target_sizes=[image.size[::-1]]
    )

    # prompt SAM image predictor to get the mask for the object
    image_predictor.set_image(np.array(image.convert("RGB")))

    # process the detection results
    input_boxes = results[0]["boxes"] # .cpu().numpy()
    # print("results[0]",results[0])
    OBJECTS = results[0]["labels"]
    if input_boxes.shape[0] != 0:

        # prompt SAM 2 image predictor to get the mask for the object
        masks, scores, logits = image_predictor.predict(
            point_coords=None,
            point_labels=None,
            box=input_boxes,
            multimask_output=False,
        )
        # convert the mask shape to (n, H, W)
        if masks.ndim == 2:
            masks = masks[None]
            scores = scores[None]
            logits = logits[None]
        elif masks.ndim == 4:
            masks = masks.squeeze(1)
        """
        Step 3: Register each object's positive points to video predictor
        """

        # If you are using point prompts, we uniformly sample positive points based on the mask
        if mask_dict.promote_type == "mask":
            mask_dict.add_new_frame_annotation(mask_list=torch.tensor(masks).to(device), box_list=torch.tensor(input_boxes), label_list=OBJECTS)
        else:
            raise NotImplementedError("SAM 2 video predictor only support mask prompts")
    else:
        print("No object detected in the frame, skip merge the frame merge {}".format(frame_names[start_frame_idx]))
        mask_dict = sam2_masks

    """
    Step 4: Propagate the video predictor to get the segmentation results for each frame
    """
    objects_count = mask_dict.update_masks(tracking_annotation_dict=sam2_masks, iou_threshold=0.8, objects_count=objects_count)
    frame_object_count[start_frame_idx] = objects_count
    print("objects_count", objects_count)
    
    if len(mask_dict.labels) == 0:
        mask_dict.save_empty_mask_and_json(mask_data_dir, json_data_dir, image_name_list = frame_names[start_frame_idx:start_frame_idx+step])
        print("No object detected in the frame, skip the frame {}".format(start_frame_idx))
        continue
    else:
        video_predictor.reset_state(inference_state)

        for object_id, object_info in mask_dict.labels.items():
            frame_idx, out_obj_ids, out_mask_logits = video_predictor.add_new_mask(
                    inference_state,
                    start_frame_idx,
                    object_id,
                    object_info.mask,
                )
        
        video_segments = {}  # output the following {step} frames tracking masks
        for out_frame_idx, out_obj_ids, out_mask_logits in video_predictor.propagate_in_video(inference_state, max_frame_num_to_track=step, start_frame_idx=start_frame_idx):
            frame_masks = MaskDictionaryModel()
            
            for i, out_obj_id in enumerate(out_obj_ids):
                out_mask = (out_mask_logits[i] > 0.0) # .cpu().numpy()
                object_info = ObjectInfo(instance_id = out_obj_id, mask = out_mask[0], class_name = mask_dict.get_target_class_name(out_obj_id), logit=mask_dict.get_target_logit(out_obj_id))
                object_info.update_box()
                frame_masks.labels[out_obj_id] = object_info
                image_base_name = frame_names[out_frame_idx].split(".")[0]
                frame_masks.mask_name = f"mask_{image_base_name}.npy"
                frame_masks.mask_height = out_mask.shape[-2]
                frame_masks.mask_width = out_mask.shape[-1]

            video_segments[out_frame_idx] = frame_masks
            sam2_masks = copy.deepcopy(frame_masks)

        print("video_segments:", len(video_segments))
    """
    Step 5: save the tracking masks and json files
    """
    for frame_idx, frame_masks_info in tqdm(video_segments.items(), desc="Saving Tracking Masks", total=len(video_segments)):
        mask = frame_masks_info.labels
        mask_img = torch.zeros(frame_masks_info.mask_height, frame_masks_info.mask_width)
        for obj_id, obj_info in mask.items():
            mask_img[obj_info.mask == True] = obj_id

        mask_img = mask_img.numpy().astype(np.uint16)
        np.save(os.path.join(mask_data_dir, frame_masks_info.mask_name), mask_img)

        json_data_path = os.path.join(json_data_dir, frame_masks_info.mask_name.replace(".npy", ".json"))
        frame_masks_info.to_json(json_data_path)
       

CommonUtils.draw_masks_and_box_with_supervision(video_dir, mask_data_dir, json_data_dir, result_dir)
if REVERSE_TRACK:
    for d in [mask_data_dir, json_data_dir, result_dir]:
        reverse_files(d)

create_video_from_images(result_dir, output_video_path, frame_rate=15)
# Out:
# frame loading (JPEG / PNG): 100%|██████████| 330/330 [00:10<00:00, 31.94it/s]
# Total frames: 330
# start_frame_idx 0
# UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# UserWarning: cannot import name '_C' from 'sam2' (/scratch/xz653/code/shape-of-motion/Grounded-SAM-2/sam2/__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
# objects_count 2
# propagate in video: 100%|██████████| 330/330 [01:16<00:00,  4.34it/s]
# video_segments: 330
# Saving Tracking Masks: 100%|██████████| 330/330 [00:02<00:00, 125.28it/s]
# Path '/scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result' did not exist and has been created.
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00000.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00001.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00002.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00003.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00004.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00005.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00006.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00007.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00008.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00009.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00010.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00011.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00012.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00013.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00014.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00015.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00016.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00017.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00018.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00019.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00020.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00021.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00022.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00023.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00024.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00025.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00026.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00027.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00028.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00029.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00030.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00031.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00032.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00033.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00034.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00035.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00036.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00037.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00038.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00039.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00040.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00041.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00042.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00043.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00044.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00045.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00046.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00047.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00048.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00049.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00050.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00051.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00052.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00053.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00054.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00055.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00056.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00057.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00058.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00059.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00060.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00061.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00062.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00063.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00064.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00065.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00066.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00067.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00068.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00069.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00070.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00071.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00072.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00073.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00074.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00075.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00076.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00077.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00078.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00079.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00080.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00081.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00082.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00083.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00084.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00085.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00086.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00087.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00088.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00089.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00090.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00091.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00092.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00093.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00094.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00095.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00096.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00097.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00098.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00099.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00100.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00101.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00102.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00103.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00104.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00105.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00106.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00107.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00108.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00109.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00110.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00111.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00112.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00113.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00114.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00115.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00116.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00117.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00118.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00119.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00120.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00121.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00122.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00123.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00124.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00125.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00126.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00127.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00128.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00129.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00130.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00131.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00132.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00133.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00134.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00135.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00136.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00137.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00138.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00139.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00140.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00141.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00142.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00143.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00144.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00145.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00146.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00147.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00148.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00149.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00150.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00151.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00152.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00153.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00154.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00155.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00156.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00157.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00158.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00159.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00160.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00161.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00162.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00163.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00164.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00165.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00166.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00167.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00168.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00169.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00170.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00171.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00172.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00173.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00174.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00175.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00176.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00177.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00178.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00179.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00180.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00181.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00182.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00183.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00184.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00185.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00186.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00187.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00188.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00189.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00190.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00191.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00192.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00193.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00194.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00195.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00196.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00197.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00198.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00199.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00200.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00201.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00202.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00203.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00204.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00205.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00206.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00207.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00208.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00209.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00210.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00211.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00212.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00213.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00214.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00215.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00216.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00217.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00218.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00219.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00220.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00221.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00222.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00223.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00224.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00225.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00226.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00227.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00228.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00229.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00230.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00231.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00232.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00233.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00234.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00235.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00236.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00237.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00238.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00239.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00240.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00241.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00242.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00243.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00244.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00245.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00246.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00247.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00248.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00249.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00250.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00251.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00252.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00253.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00254.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00255.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00256.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00257.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00258.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00259.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00260.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00261.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00262.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00263.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00264.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00265.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00266.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00267.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00268.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00269.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00270.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00271.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00272.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00273.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00274.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00275.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00276.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00277.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00278.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00279.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00280.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00281.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00282.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00283.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00284.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00285.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00286.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00287.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00288.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00289.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00290.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00291.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00292.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00293.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00294.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00295.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00296.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00297.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00298.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00299.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00300.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00301.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00302.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00303.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00304.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00305.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00306.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00307.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00308.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00309.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00310.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00311.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00312.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00313.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00314.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00315.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00316.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00317.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00318.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00319.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00320.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00321.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00322.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00323.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00324.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00325.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00326.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00327.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00328.jpg
# Annotated image saved as /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/result/0_00329.jpg
# ['0_00000.jpg', '0_00001.jpg', '0_00002.jpg', '0_00003.jpg', '0_00004.jpg', '0_00005.jpg', '0_00006.jpg', '0_00007.jpg', '0_00008.jpg', '0_00009.jpg', '0_00010.jpg', '0_00011.jpg', '0_00012.jpg', '0_00013.jpg', '0_00014.jpg', '0_00015.jpg', '0_00016.jpg', '0_00017.jpg', '0_00018.jpg', '0_00019.jpg', '0_00020.jpg', '0_00021.jpg', '0_00022.jpg', '0_00023.jpg', '0_00024.jpg', '0_00025.jpg', '0_00026.jpg', '0_00027.jpg', '0_00028.jpg', '0_00029.jpg', '0_00030.jpg', '0_00031.jpg', '0_00032.jpg', '0_00033.jpg', '0_00034.jpg', '0_00035.jpg', '0_00036.jpg', '0_00037.jpg', '0_00038.jpg', '0_00039.jpg', '0_00040.jpg', '0_00041.jpg', '0_00042.jpg', '0_00043.jpg', '0_00044.jpg', '0_00045.jpg', '0_00046.jpg', '0_00047.jpg', '0_00048.jpg', '0_00049.jpg', '0_00050.jpg', '0_00051.jpg', '0_00052.jpg', '0_00053.jpg', '0_00054.jpg', '0_00055.jpg', '0_00056.jpg', '0_00057.jpg', '0_00058.jpg', '0_00059.jpg', '0_00060.jpg', '0_00061.jpg', '0_00062.jpg', '0_00063.jpg', '0_00064.jpg', '0_00065.jpg', '0_00066.jpg', '0_00067.jpg', '0_00068.jpg', '0_00069.jpg', '0_00070.jpg', '0_00071.jpg', '0_00072.jpg', '0_00073.jpg', '0_00074.jpg', '0_00075.jpg', '0_00076.jpg', '0_00077.jpg', '0_00078.jpg', '0_00079.jpg', '0_00080.jpg', '0_00081.jpg', '0_00082.jpg', '0_00083.jpg', '0_00084.jpg', '0_00085.jpg', '0_00086.jpg', '0_00087.jpg', '0_00088.jpg', '0_00089.jpg', '0_00090.jpg', '0_00091.jpg', '0_00092.jpg', '0_00093.jpg', '0_00094.jpg', '0_00095.jpg', '0_00096.jpg', '0_00097.jpg', '0_00098.jpg', '0_00099.jpg', '0_00100.jpg', '0_00101.jpg', '0_00102.jpg', '0_00103.jpg', '0_00104.jpg', '0_00105.jpg', '0_00106.jpg', '0_00107.jpg', '0_00108.jpg', '0_00109.jpg', '0_00110.jpg', '0_00111.jpg', '0_00112.jpg', '0_00113.jpg', '0_00114.jpg', '0_00115.jpg', '0_00116.jpg', '0_00117.jpg', '0_00118.jpg', '0_00119.jpg', '0_00120.jpg', '0_00121.jpg', '0_00122.jpg', '0_00123.jpg', '0_00124.jpg', '0_00125.jpg', '0_00126.jpg', '0_00127.jpg', '0_00128.jpg', '0_00129.jpg', '0_00130.jpg', '0_00131.jpg', '0_00132.jpg', '0_00133.jpg', '0_00134.jpg', '0_00135.jpg', '0_00136.jpg', '0_00137.jpg', '0_00138.jpg', '0_00139.jpg', '0_00140.jpg', '0_00141.jpg', '0_00142.jpg', '0_00143.jpg', '0_00144.jpg', '0_00145.jpg', '0_00146.jpg', '0_00147.jpg', '0_00148.jpg', '0_00149.jpg', '0_00150.jpg', '0_00151.jpg', '0_00152.jpg', '0_00153.jpg', '0_00154.jpg', '0_00155.jpg', '0_00156.jpg', '0_00157.jpg', '0_00158.jpg', '0_00159.jpg', '0_00160.jpg', '0_00161.jpg', '0_00162.jpg', '0_00163.jpg', '0_00164.jpg', '0_00165.jpg', '0_00166.jpg', '0_00167.jpg', '0_00168.jpg', '0_00169.jpg', '0_00170.jpg', '0_00171.jpg', '0_00172.jpg', '0_00173.jpg', '0_00174.jpg', '0_00175.jpg', '0_00176.jpg', '0_00177.jpg', '0_00178.jpg', '0_00179.jpg', '0_00180.jpg', '0_00181.jpg', '0_00182.jpg', '0_00183.jpg', '0_00184.jpg', '0_00185.jpg', '0_00186.jpg', '0_00187.jpg', '0_00188.jpg', '0_00189.jpg', '0_00190.jpg', '0_00191.jpg', '0_00192.jpg', '0_00193.jpg', '0_00194.jpg', '0_00195.jpg', '0_00196.jpg', '0_00197.jpg', '0_00198.jpg', '0_00199.jpg', '0_00200.jpg', '0_00201.jpg', '0_00202.jpg', '0_00203.jpg', '0_00204.jpg', '0_00205.jpg', '0_00206.jpg', '0_00207.jpg', '0_00208.jpg', '0_00209.jpg', '0_00210.jpg', '0_00211.jpg', '0_00212.jpg', '0_00213.jpg', '0_00214.jpg', '0_00215.jpg', '0_00216.jpg', '0_00217.jpg', '0_00218.jpg', '0_00219.jpg', '0_00220.jpg', '0_00221.jpg', '0_00222.jpg', '0_00223.jpg', '0_00224.jpg', '0_00225.jpg', '0_00226.jpg', '0_00227.jpg', '0_00228.jpg', '0_00229.jpg', '0_00230.jpg', '0_00231.jpg', '0_00232.jpg', '0_00233.jpg', '0_00234.jpg', '0_00235.jpg', '0_00236.jpg', '0_00237.jpg', '0_00238.jpg', '0_00239.jpg', '0_00240.jpg', '0_00241.jpg', '0_00242.jpg', '0_00243.jpg', '0_00244.jpg', '0_00245.jpg', '0_00246.jpg', '0_00247.jpg', '0_00248.jpg', '0_00249.jpg', '0_00250.jpg', '0_00251.jpg', '0_00252.jpg', '0_00253.jpg', '0_00254.jpg', '0_00255.jpg', '0_00256.jpg', '0_00257.jpg', '0_00258.jpg', '0_00259.jpg', '0_00260.jpg', '0_00261.jpg', '0_00262.jpg', '0_00263.jpg', '0_00264.jpg', '0_00265.jpg', '0_00266. ...
# 100%|██████████| 330/330 [00:03<00:00, 91.07it/s]
# Video saved at /scratch/xz653/datasets/iphone/pillow/flow3d_preprocessed/grounding_sam2/output.mp4
